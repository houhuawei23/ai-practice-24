# %%
import torch
import clip
from PIL import Image
import json

# %%
# read the caption

with open("./dataset1/caption.json", "r") as f:
    captions = json.load(f)

print(captions[0])
caption_list = [item["caption"] for item in captions]
print(caption_list[0])
# Out:
# {'caption': 'A woman strides purposefully along the sidewalk, her determined footsteps echoing against the pavement, another person trailing behind her, their connection palpable in the shared rhythm of their journey, a silent companion in the hustle and bustle of city life.'}
# A woman strides purposefully along the sidewalk, her determined footsteps echoing against the pavement, another person trailing behind her, their connection palpable in the shared rhythm of their journey, a silent companion in the hustle and bustle of city life.

# %%
# caption_list

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")

# Load the CLIP model
model, preprocess = clip.load("ViT-B/32", device=device)

# captions_tensor = clip.tokenize(caption_list) .to(device)
# use ground truth keywords
# with open("./dataset1/caption_with_keywords_and_image.json") as f:
#     caption_with_keywords_and_image = json.load(f)
#     keywords_list = [
#         caption_with_keywords_and_image[i]["keywords"]
#         for i in range(len(caption_with_keywords_and_image))
#     ]

# use our keywords extractor
# from keywords_extract import keyWords_extractor
# keywords_list = keyWords_extractor(caption_list)

# just cut-off to 50 words
keywords_list = [caption[:100] for caption in caption_list]

captions_tensor = clip.tokenize(keywords_list).to(device)

images_path = "./dataset1/images/"

import os

# Load the images and preprocess them
images_files = os.listdir(images_path)

images = [Image.open(images_path + f).convert("RGB") for f in os.listdir(images_path)]

images_preprocessed = torch.stack([preprocess(img) for img in images]).to(device)

# Calculate the similarity between the images and the captions

with torch.no_grad():
    image_features = model.encode_image(images_preprocessed)
    text_features = model.encode_text(captions_tensor)
    logits_per_image, logits_per_text = model(images_preprocessed, captions_tensor)
    probs = logits_per_image.softmax(dim=-1).cpu().numpy()
# Out:
# Using cpu device

# %%
print("Probs: ")
print(probs)
# Out:
# Probs:
# [[7.9535075e-06 6.8679224e-06 4.8940943e-05 ... 1.0980217e-03
#   1.3712856e-03 9.8176561e-06]
#  [1.4260755e-01 3.5847243e-04 1.6039809e-03 ... 3.8078886e-02
#   7.4589049e-04 5.8586800e-05]
#  [6.4762658e-04 1.2082123e-03 2.2343642e-03 ... 2.3080202e-05
#   3.6907075e-03 6.3022613e-05]
#  ...
#  [5.8202096e-04 4.3607345e-03 2.5659683e-04 ... 1.4793727e-03
#   8.3014145e-03 2.1034850e-05]
#  [2.7330357e-04 6.7435336e-05 5.7825902e-05 ... 7.6040911e-04
#   5.4055099e-06 1.2202881e-06]
#  [2.2583558e-06 1.7289838e-06 1.7826102e-05 ... 1.3346554e-08
#   2.8493348e-06 3.0785362e-08]]

# %%
import numpy as np

images_files = os.listdir(images_path)


# select the best image for each caption
best_image_indices = np.argmax(probs, axis=0)
# print image paths for the best images
best_image_paths = [images_files[i] for i in best_image_indices]
for i in range(len(best_image_paths)):
    print(f"Caption: {keywords_list[i]}")
    print(f"Best image: {best_image_paths[i]}")
    print("-")
# Out:
# Caption: A woman strides purposefully along the sidewalk, her determined footsteps echoing against the paveme
# Best image: 4726926550.jpg
# -
# Caption: A woman wearing glasses smiles with satisfaction as she reviews the images on the back of her camera
# Best image: 339734472.jpg
# -
# Caption: Clad in a crisp blue apron and a neatly tied headscarf, the man stands with determination behind the
# Best image: 345412253.jpg
# -
# Caption: In a busy city teeming with cars stuck in traffic along the road, a lone man pauses to observe the c
# Best image: 3019748495.jpg
# -
# Caption: In the heat of the baseball game, a runner finds themselves caught off balance as they attempt to st
# Best image: 3731742056.jpg
# -
# Caption: With skill and precision, the boy executes a flawless skateboard trick off the metal plank, his move
# Best image: 6222964233.jpg
# -
# Caption: In the bubbly embrace of the bathtub, a child playfully blows water out of their mouth, their laught
# Best image: 836828001.jpg
# -
# Caption: Shielding his eyes from the sun's glare, the man squints into the camera lens as he stands on the sa
# Best image: 4455946038.jpg
# -
# Caption: With skill and precision, a boy executes a daring trick atop a guardrail on his inline skates, his b
# Best image: 4592269543.jpg
# -
# Caption: Clad in black and gold kilted uniforms, the men stand in a circle in the grassy park, their bagpipes
# Best image: 179122558.jpg
# -
# Caption: City workers clad in bright yellow and green safety suits trudge through the snow, their determinati
# Best image: 4199756372.jpg
# -
# Caption: Dressed in vibrant yellow and red vests, the workers diligently scrub and polish the windows of the
# Best image: 4970493587.jpg
# -
# Caption: Illuminated by the soft glow of the street lamps, the cityscape at night is a tapestry of shadows an
# Best image: 4451567464.jpg
# -
# Caption: A tennis player dressed in a crisp white outfit focuses intently as they swing for the ball, their f
# Best image: 7564442710.jpg
# -
# Caption: A young woman wearing a pink hooded shirt attempts to drink water from an outside shower, the refres
# Best image: 455709958.jpg
# -
# Caption: A man wearing a striking black and red striped shirt strikes a confident pose next to a majestic lio
# Best image: 4895355979.jpg
# -
# Caption: A woman tilts her face upward, her eyes closed in a moment of quiet reflection, as she lifts her whi
# Best image: 6034227204.jpg
# -
# Caption: A weary-looking Hispanic man, clad in a white long-sleeved shirt, takes a moment to rest as he sits
# Best image: 2680852294.jpg
# -
# Caption: Boys eagerly set up their makeshift stall on the sidewalk, offering an array of goods including flow
# Best image: 4410008455.jpg
# -
# Caption: Two women clad in gray sleeveless tops disembark from a bus, their arms laden with belongings as the
# Best image: 196371457.jpg
# -
# Caption: With laughter and chatter filling the air, school children stand in a line outside a yellow building
# Best image: 5506988830.jpg
# -
# Caption: In serene harmony with their surroundings, the man dressed in white and the woman draped in regal pu
# Best image: 4269809096.jpg
# -
# Caption: Three young girls, dressed alike in charming plaid skirts, hats, green sweaters, and blue knee socks
# Best image: 2340568853.jpg
# -
# Caption: Captured in a side profile, a distinguished man with a mustache and goatee cuts a striking figure as
# Best image: 2229180161.jpg
# -
# Caption: A man strums a guitar next to another seated companion, who operates a green cart while wearing a ma
# Best image: 3293018193.jpg
# -
# Caption: Amidst the pulsating energy of the rock concert, the lead singer commands the stage, their voice cut
# Best image: 6309331514.jpg
# -
# Caption: Amidst the bustling atmosphere of a buffet line, people eagerly fill their plates with an array of d
# Best image: 4367621919.jpg
# -
# Caption: Along the banks of the river, many people gather atop large stones that span the width of the rushin
# Best image: 4872137574.jpg
# -
# Caption: A Chinese man sporting a cap navigates through the streets on his bicycle, a bouquet of vibrant flow
# Best image: 5225752827.jpg
# -
# Caption: Clad in fatigues, a man kneels down with precision, meticulously tucking the sheet under the mattres
# Best image: 3142675162.jpg
# -
# Caption: In perfect alignment, a group of white and black birds perch on a concrete wall, their feathers ruff
# Best image: 3409326324.jpg
# -
# Caption: Amidst the untouched expanse of pristine snow, a white dog dashes around with unbridled joy, its fur
# Best image: 2295894587.jpg
# -

# %%
# save to result.json
result = []
for i in range(len(best_image_paths)):
    result.append(
        {
            "caption": caption_list[i],
            "keywords": keywords_list[i],
            "image": best_image_paths[i],
        }
    )

with open("result_cutoff_100.json", "w") as f:
    json.dump(result, f, indent=4)

# %%
print(probs.shape)
len(images)
len(keywords_list)
best_image_indices.shape
# Out:
# (300, 60)
# (300,)

# %%
from keywords_extract import keyWords_extractor

res = keyWords_extractor(caption_list)

# %%
# len(res)
res
# Out:
# ['footsteps, purposefully, trailing, bustle, companion',
#  'creative, curve, eye, frame, fulfillment',
#  'hammer, purpose, bringing, channeling, comforting',
#  'busy, cars, contemplative, crowds, ebb',
#  'bygone, clip, clop, cobbled, era',
#  'bodies, existence, faithful, historic, location',
#  'cuff, adjusts, arm, blood, carefully',
#  'burgers, come, donning, drawing, eager',
#  'animated, beneath, cadence, jumpsuits, sway',
#  'adrenaline, aircraft, board, fueled, helicopter',
#  'aerial, breathtaking, checkered, open, performs',
#  'center, culture, elegantly, mesmerizing, perform',
#  'boxing, defensive, delivers, gear, impact',
#  'devices, floating, gleefully, infectious, pair',
#  'trees, tranquil, wilderness, embrace, sense',
#  'adversity, bundled, chill, earmuffs, forward',
#  'background, dimly, extinguisher, figures, foreground',
#  'air, breathless, cheering, defying, fans',
#  'figure, animal, astride, countryside, equestrian',
#  'friendship, banter, barriers, blooming, blossoms',
#  'carve, exhilarating, finesse, invigorating, pile',
#  'blue, blonde, color, concentration, craftsmanship',
#  'beckoning, distance, fusion, outdoor, practicality',
#  'alive, attention, charged, early, emblazoned',
#  'carefree, contentment, drenched, dry, explores',
#  'bridge, clack, click, heart, horizons',
#  'close, holding, melody, midst, noise',
#  'bustling, addition, curious, girl, restaurant',
#  'canine, collar, gleaming, markings, proudly',
#  '16, 25, breath, hanging, holds',
#  'bag, catches, clear, dances, dazzling',
#  'colleagues, computers, effortlessly, goal, immersed',
#  'balance, attempt, avoiding, base, caught',
#  'athleticism, conquers, flawless, metal, plank',
#  'bath, bathtub, blows, bubbly, everyday',
#  'sun, basks, beach, bucket, fun',
#  'blur, fearless, guardrail, inline, skates',
#  'bagpipes, circle, cultural, expressions, gold',
#  'safety, bright, cones, contrasting, haul',
#  'cleanliness, dangle, diligently, gleam, harnesses',
#  'brick, cable, car, couple, jungle',
#  'ball, court, focuses, intently, outfit',
#  'water, attempts, cascade, coolness, drink',
#  'lion, man, presence, moment, adds',
#  'gesture, closed, gloved, gratitude, imbued',
#  'endeavors, heavy, hispanic, introspection, long',
#  'age, boys, commerce, community, drinks',
#  'determination, belongings, bus, chapter, disembark',
#  'chatter, children, contagious, school, stories',
#  'cranes, draped, sit, waterside, boat',
#  'hand, alike, hats, knee, plaid',
#  'authority, distinguished, exuding, goatee, mustache',
#  'artistic, collaboration, guitar, mask, operates',
#  'audience, commands, concert, cutting, darkness',
#  'buffet, delectable, delight, dishes, plates',
#  'alight, banks, currents, flowing, large',
#  'adorning, basket, bouquet, cap, chinese',
#  'attends, bed, discipline, fatigues, mattress',
#  'alignment, architecture, birds, concrete, feathers',
#  'dog, spirited, fleeting, leap, pure']
